# %% [markdown]
# # Assignment Name

# %% [markdown]
# This is the assignment template that should be followed when making/revising them. The template not only includes the structure of revising them, but also includes some rules that should be followed during the process. These rules (below) are divided by section/subsections in the Table of Content.

# %% [markdown]
# __Introduction__
#
# The very first thing should be the assignment name, for this example we have named the assignment __Assignment Name__ (above). For the assignment name we should use Heading Level 1 (#)
#
# Next, the introduction part (not necessarily should contain the heading "introduction") should tell the learners about
# - what the assignment is
# - what is it about
# - what they will learn in it.

# %% [markdown]
# ## Table of Content
#
# - [1 - Sections](#1)
#   - [1.1 - Sub-Section](#1-1)
#     - [1.1.1 - Second Sub-Section](#1-1-1)
#         - [Exercise 1](#ex-1)
#         - [Exercise 2 - name of the exercise](#ex-2)
# - [2 - For our Learners](#2)
#   - [2.1 - Addressing our Learners](#2-1)
#   - [2.2 - Markdown](#2-2)
#   - [Exercise 3 - with expected outputs](#ex-3)
#   - [Exercise 4 - with hints](#ex-4)
# - [3 - Development](#3)
#   - [3.1 - Workspaces](#3-1)
#     - [3.1.1 - Student Workspace](#3-1-1)
#     - [3.1.2 - Instructor Workspace](#3-1-2)
#     - [3.1.3 - Colab Workspace](#3-1-3)
#   - [3.2 - Creating the Solution/Student facing assignment version](#3-2)
#     - [3.2.1 - Solution Assignment Version](#3-2-1)
#     - [3.2.2 - Student Facing Assignment Version](#3-2-2)
#   - [3.3 - GitHub](#3-3)
#     - [3.3.1 - Branching](#3-3-1)
#     - [3.3.2 - Regular Pushes](#3-3-2)
#     - [3.3.3 - Commit Names](#3-3-3)
#     - [3.3.4 - Keeping the Repo Updated](#3-3-4)
# - [4 - Deployment](#4)

# %% [markdown]
# <a name='1'></a>
# ## 1 - Sections
#
# The assignment should be divided into sections/subsections. For Sections we'll use Heading Level 2 (##)

# %%
# some code

# %% [markdown]
# <a name='1-1'></a>
# ### 1.1 - Sub-Section
#
# For first level sub-section we'll use Heading Level 3 (###)

# %%
# some code

# %% [markdown]
# <a name='1-1-1'></a>
# #### 1.1.1 - Second Sub-Section
#
# For second level sub-section we'll use Heading Level 4 (####)

# %%
# some code

# %% [markdown]
# <a name='ex-1'></a>
# ### Exercise 1
#
# For Exercises you'll _always_ use Heading Level 3 (###), regardless of which level of section/sub-section it falls in.
#
# Exercise # should also be mentioned next to the Exercise heading.

# %%
# some code

# %% [markdown]
# <a name='ex-2'></a>
# ### Exercise 2 - name of the exercise
#
# Usually a student is asked to fill in a graded function. When this applies, next to the exercise number mention the graded function as well which will be considered as that particular exercise's name.
#
# Where this does not apply follow the simple format as shown for `Exercise 1` above

# %%
# some code

# %% [markdown]
# <a name='2'></a>
# ## 2 - For our Learners

# %% [markdown]
# <a name='2-1'></a>
# ### 2.1 - Addressing our Learners
#
# When addressing the learners avoid the use of "we" and instead use "you".

# %% [markdown]
# <a name='2-2'></a>
# ### 2.2 - Markdown
#
# Markdowns, with the help of illustrations whenever possible, should be written in such a way that a learner should not feel the need to look for information elsewhere. Everything required should be mentioned within the assignment.
#
# Provide hyperlinks to Documentations as well so that learners could explore on their own. When providing hyperlinks, double check to make sure they don't run into an error.
#
# Also, make sure the provided documentation link is relevant.

# %% [markdown]
# <a name='ex-3'></a>
# ### Exercise 3 - expected output
#
# Whenever possible provide an expected output to the learners against which they can match their actual output. _When the expected output is an __estimated__ value(s), be sure to mention it._
#
# Use Heading Level 5 (#####) and bold for Expected Output

# %%
# some code

# %%
# some test

# %% [markdown]
# ##### __Expected Output__
#
# ```Python
# df1
#    patient_id
# 0           0
# 1           1
# 2           2
# df2
#    patient_id
# 0           2
# 1           3
# 2           4
# leakage output: True
#
# ```

# %% [markdown]
# <a name='ex-4'></a>
# ### Exercise 4 - with hints
#
# When an Exercise is challenging, provide the learners with hints (outside of the code block).
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li> Make use of python's set.intersection() function. </li>
#     <li> In order to match the automatic grader's expectations, please start the line of code with <code>df1_patients_unique...[continue your code here]</code> </li>
#
# </ul>
# </p>

# %% [markdown]
# <a name='3'></a>
# ## 3 - Development
#
# Below are some rules and best practices to follow during the development phase of the course and assignments.

# %% [markdown]
# <a name='3-1'></a>
# ### 3.1 - Workspaces

# %%
# some code

# %% [markdown]
# <a name='3-1-1'></a>
# #### 3.1.1 - Student Workspace
#
# If the Lab Image is created and the student workspace is available, it is recommended to use that when working on the assignment, as it is the environment in which the assignment will eventually run. The Lab image will have all the necessary packages and dependencies required to run the particular assignment. This way you test out the Lab image as well.
#
# One other advantage of the student workspace is that you don't have to worry about multiple people working on the same assignment as you'll be working on your own copy of it.

# %%
# some code

# %% [markdown]
# <a name='3-1-2'></a>
# #### 3.1.2 - Instructor Workspace
#
# _Be very critical about working in the instructor workspace._
#
# Work in the instructor workspace only if:
# - it is necessary, in which case inform your team beforehand.
# - it is decided by the team collectively to work in the instructor workspace.
#
# To be on the safe side, when working within the instructor workspace regularly download the assignment and push it into the GitHub repo.
#
# Also, make it a habit that everytime you leave the intructor workspace you press _Kernel -> Restart & Clear Output_

# %%
# some code

# %% [markdown]
# <a name='3-1-3'></a>
# #### 3.1.3 - Colab Workspace
#
# - We make colab versions when we want to use GPUs, so to make this easier for us and our learners do:
#
#       Runtime -->  Change runtime type --> Hardware accelerator --> GPU --> Save
#
#       Next do:
#
#       File --> Save
#
#   Now everytime anyone opens the colab the settings will be set to GPU.
#
# - When you are done working on the colab make a habit of clearing the outputs and restarting the runtime before exiting. You can do those by clicking:
#
#       Edit --> Clear all outputs
#
#       Runtime --> Restart runtime
#
# - Always set the colab settings as such where the learners cannot edit and save it. Ask them to make a copy of it in their own drive for this purpose.

# %%
# some code

# %% [markdown]
# <a name='3-2'></a>
# ### 3.2 - Creating the Solution/Student facing assignment version
#
# In both the scenarios described below, in the solution version make sure you don't leave behind any important information for the eyes of our mentors as those solution versions will be shared with them.

# %% [markdown]
# <a name='3-2-1'></a>
# #### 3.2.1 - Solution Assignment Version
#
# If you are using nbgrader for the assignments, in which case a student facing version is automatically generated by it, you'd need to create the Solution version of the assignment, for our reference and to be shared with our mentors.
#
# _The Solution assignment version should have the "Submit Assignment" button in it as well._
#
# Create the Solution version only after you are completely satisfied with revising the assignment.

# %%
# some code

# %% [markdown]
# <a name='3-2-2'></a>
# #### 3.2.2 - Student Facing Assignment Version
#
# For assignments where we create the solution version first, be completely satisfied with the revision before generating the student facing version out of it.
#
# _The Solution assignment version should have the "Submit Assignment" button in it as well._

# %%
# some code

# %% [markdown]
# <a name='3-3'></a>
# ### 3.3 - GitHub
#
# *To be added*

# %%
# some code

# %% [markdown]
# <a name='3-3-1'></a>
# #### 3.3.1 - Branching
#
# Avoid working in the `master` branch, unless instructed by the team or informing them beforehand.
#
# For all your edits and revisions branch out of the master branch, work on it and then raise a pull request, asking for a review.

# %%
# some code

# %% [markdown]
# <a name='3-3-2'></a>
# #### 3.3.2 - Regular Pushes
#
# Be regular with your pushes into your branch with your edits and revisions

# %% [markdown]
# <a name='3-3-3'></a>
# #### 3.3.3 - Commit Names
#
# In your commits mention, at least, the course #, week # and the item you have worked on so that the team knows where the changes were made.

# %%
# some code

# %% [markdown]
# <a name='3-3-4'></a>
# #### 3.3.4 Keeping the Repo Updated
#
# Be vocal about your pushes and progress with your team so that they know where can they find the latest copy of the item they are looking for or have to work on.

# %% [markdown]
# <a name='4'></a>
# ## 4. Deployment
#
# *To be added*

# %%
# some code
